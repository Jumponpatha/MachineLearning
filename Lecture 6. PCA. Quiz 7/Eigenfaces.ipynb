# %% [markdown]
# Copied from https://colab.research.google.com/github/AnaHristian/intro_to_machine_learning/blob/master/eigenfaces.ipynb

# %% [markdown]
# ## [Faces recognition example using eigenfaces and SVMs](https://scikit-learn.org/stable/auto_examples/applications/plot_face_recognition.html)

# %%
import tarfile
from time import time
import logging
import pylab as pl
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.datasets import fetch_lfw_people
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA as RandomizedPCA
from sklearn.svm import SVC

# %%
# !wget http://vis-www.cs.umass.edu/lfw/lfw-funneled.tgz
# Out:
# --2024-03-16 08:00:43--  http://vis-www.cs.umass.edu/lfw/lfw-funneled.tgz
# Resolving vis-www.cs.umass.edu (vis-www.cs.umass.edu)... 128.119.244.95
# Connecting to vis-www.cs.umass.edu (vis-www.cs.umass.edu)|128.119.244.95|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 243346528 (232M) [application/x-gzip]
# Saving to: ‘lfw-funneled.tgz’
#
# lfw-funneled.tgz    100%[===================>] 232.07M  2.83MB/s    in 2m 17s
#
# 2024-03-16 08:03:00 (1.70 MB/s) - ‘lfw-funneled.tgz’ saved [243346528/243346528]

# %% [markdown]
# Welcome to Labeled Faces in the Wild, a database of face photographs designed for studying the problem of unconstrained face recognition. The data set contains more than 13,000 images of faces collected from the web. Each face has been labeled with the name of the person pictured. 1680 of the people pictured have two or more distinct photos in the data set. The only constraint on these faces is that they were detected by the Viola-Jones face detector. More details can be found in the technical report below.
#
# There are now four different sets of LFW images including the original and three different types of "aligned" images. The aligned images include "funneled images" (ICCV 2007), LFW-a, which uses an unpublished method of alignment, and "deep funneled" images (NIPS 2012). Among these, LFW-a and the deep funneled images produce superior results for most face verification algorithms over the original images and over the funneled images (ICCV 2007).

# %%
# %%time
tfile = tarfile.open("lfw-funneled.tgz", "r:gz")
tfile.extractall(".")
# Out:
# CPU times: user 4.85 s, sys: 2.51 s, total: 7.36 s
# Wall time: 7.6 s

# %%
# Display progress logs on stdout
logging.basicConfig(level=logging.INFO, format='%(asctime)s %(message)s')

# %%
# Download the data, if not already on disk and load it as numpy arrays
# This uses the metadata to align each image in the LFW database
# For metadata info read:
#  https://datagen.tech/guides/image-datasets/lfw-dataset/#:~:text=Labeled%20Faces%20in%20the%20Wild%20(LFW)%20is%20an%20image%20dataset,collected%20from%20across%20the%20web.

lfw_people = fetch_lfw_people(min_faces_per_person=70, resize=0.4)

# %%
# introspect the images arrays to find the shapes (for plotting)
n_samples, h, w = lfw_people.images.shape
np.random.seed(42)

# %%
n_samples, h, w
# Out:
# (1288, 50, 37)

# %%
# for machine learning we use the data directly (as relative pixel
# position info is ignored by this model)
X = lfw_people.data
n_features = X.shape[1]

# %%
# the label to predict is the id of the person
y = lfw_people.target
target_names = lfw_people.target_names
n_classes = target_names.shape[0]
print("target y = \n", y) #target 0-6 for 7 people
print("target names = \n", target_names)
# Out:
# target y =
#  [5 6 3 ... 5 3 5]
# target names =
#  ['Ariel Sharon' 'Colin Powell' 'Donald Rumsfeld' 'George W Bush'
#  'Gerhard Schroeder' 'Hugo Chavez' 'Tony Blair']

# %%
print("Total dataset size:")
print("n_samples: %d" % n_samples)
print("n_features: %d" % n_features) #h = 50, w = 37, total = 50*37 = 1,850.
print("n_classes: %d" % n_classes)
# Out:
# Total dataset size:
# n_samples: 1288
# n_features: 1850
# n_classes: 7

# %% [markdown]
# #### #1 Split into a training and testing set

# %%
# Split into a training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# #### #2 Compute a PCA (eigenfaces) on the face dataset (treated as unlabeled dataset)
#
# * unsupervised feature extraction / dimensionality reduction

# %%
# the original dimensionality is 1850
n_components = 150

# %%
print("Extracting the top %d eigenfaces from %d training faces" % (n_components, X_train.shape[0]))
t0 = time()
# create the PCA
pca = RandomizedPCA(n_components=n_components, whiten=True).fit(X_train)
print("done in %0.3fs" % (time() - t0))
# Out:
# Extracting the top 150 eigenfaces from 966 training faces
# done in 0.786s

# %%
# principle components of the face data
# reshape the data so they can look like pictures
eigenfaces = pca.components_.reshape((n_components, h, w)) #you get 150 images each of hxw

# %%
pca.explained_variance_ratio_
# Out:
# array([0.2086042 , 0.14046931, 0.06725658, 0.05641384, 0.0489805 ,
#        0.02742928, 0.02394791, 0.02116299, 0.0190179 , 0.01804605,
#        0.01568361, 0.0150686 , 0.01184229, 0.0103115 , 0.01028552,
#        0.00943706, 0.00863998, 0.00817821, 0.00801046, 0.0072037 ,
#        0.00673143, 0.00627224, 0.00623003, 0.00545138, 0.00516478,
#        0.00510715, 0.00496872, 0.00473863, 0.00432875, 0.00415551,
#        0.00389128, 0.00385915, 0.00358175, 0.00346088, 0.0034087 ,
#        0.00328849, 0.00317762, 0.00302014, 0.00292298, 0.00286995,
#        0.00276695, 0.00268668, 0.00261173, 0.0026045 , 0.0024585 ,
#        0.0024368 , 0.00240859, 0.0022402 , 0.00218233, 0.00213889,
#        0.00213492, 0.00207718, 0.00206597, 0.00203009, 0.00198741,
#        0.00188889, 0.00187225, 0.00185406, 0.00180089, 0.00178264,
#        0.00171047, 0.00166129, 0.00162434, 0.00159352, 0.00156956,
#        0.00152408, 0.00148669, 0.00147825, 0.00146333, 0.00145006,
#        0.00140727, 0.00139371, 0.00137373, 0.0013337 , 0.00131191,
#        0.00129502, 0.00126716, 0.00122879, 0.00121467, 0.00121073,
#        0.00119405, 0.00118902, 0.00116011, 0.00115378, 0.00113869,
#        0.00111794, 0.00108687, 0.00107947, 0.00105468, 0.0010318 ,
#        0.00102538, 0.00099185, 0.0009689 , 0.00095327, 0.00094107,
#        0.00093585, 0.00091293, 0.00089514, 0.00089105, 0.00086544,
#        0.00085798, 0.00084285, 0.00083936, 0.00082863, 0.00082284,
#        0.00080018, 0.00078735, 0.00078278, 0.00076593, 0.00076297,
#        0.00073017, 0.00072052, 0.00071442, 0.00070516, 0.00069534,
#        0.00068898, 0.00068156, 0.00067031, 0.00065787, 0.00064438,
#        0.00063871, 0.00063359, 0.00061923, 0.00060886, 0.00059925,
#        0.00059776, 0.00058905, 0.00058375, 0.00058088, 0.0005729 ,
#        0.0005614 , 0.00054893, 0.00054486, 0.00053096, 0.00052752,
#        0.00052173, 0.00051695, 0.00051235, 0.00050394, 0.00049725,
#        0.0004865 , 0.00047766, 0.00047105, 0.0004696 , 0.00045664,
#        0.00045597, 0.00044911, 0.00044415, 0.00043633, 0.00042737],
#       dtype=float32)

# %%
print("Transform input features to top 150 dimensions")
t0 = time()
# transform the data into the principle component representation
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)
print("done in %0.3fs" % (time() - t0))
# Out:
# Transform input features to top 150 dimensions
# done in 0.040s

# %% [markdown]
# #### #3 Train a SVM classification model

# %%
print("Fitting the SVC classifier to the training set")
#try many hyperparameter combinations of C, gamma for SVC
t0 = time()
param_grids = {
    'C': [1e3, 5e3, 1e4, 5e4, 1e5],
    'gamma':  [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.1]
}
# create the classifier for grid of hyperparameter options
clf = GridSearchCV(SVC(kernel='rbf', class_weight='balanced'), param_grids)
# fit the data
clf = clf.fit(X_train_pca, y_train)

print('done in %0.3fs' % (time() - t0))
print('Best estimator found in grid search:')
print(clf.best_estimator_)
# Out:
# Fitting the SVC classifier to the training set
# done in 26.953s
# Best estimator found in grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.005)

# %% [markdown]
# #### #4 Quantitative evaluation of the model quality on the test set

# %%
print("Predicting the people names on the testing set")
t0 = time()
y_pred = clf.predict(X_test_pca)
print('done in %0.3fs' % (time() - t0))
# Out:
# Predicting the people names on the testing set
# done in 0.116s

# %%
print(classification_report(y_test, y_pred, target_names=target_names))
print(confusion_matrix(y_test, y_pred, labels=range(n_classes)))
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.88      0.54      0.67        13
#      Colin Powell       0.80      0.88      0.84        60
#   Donald Rumsfeld       0.94      0.63      0.76        27
#     George W Bush       0.85      0.98      0.91       146
# Gerhard Schroeder       0.95      0.80      0.87        25
#       Hugo Chavez       1.00      0.53      0.70        15
#        Tony Blair       0.91      0.83      0.87        36
#
#          accuracy                           0.86       322
#         macro avg       0.91      0.74      0.80       322
#      weighted avg       0.87      0.86      0.86       322
#
# [[  7   1   0   5   0   0   0]
#  [  1  53   0   6   0   0   0]
#  [  0   3  17   6   0   0   1]
#  [  0   3   0 143   0   0   0]
#  [  0   1   0   3  20   0   1]
#  [  0   4   0   1   1   8   1]
#  [  0   1   1   4   0   0  30]]

# %% [markdown]
# #### #5 Qualitative evaluation of the predictions using matplotlib

# %%
#can set to print a larger sample
def plot_gallery(images, titles, h, w, n_row=6, n_col=4):
    """Helper function to plot a gallery of n_row x n_col sample portraits"""
    pl.figure(figsize=(1.8 * n_col, 2.4 * n_row))
    pl.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
    for i in range(n_row * n_col):
        pl.subplot(n_row, n_col, i + 1)
        pl.imshow(images[i].reshape((h, w)), cmap=pl.cm.gray)
        pl.title(titles[i], size=12)
        pl.xticks(())
        pl.yticks(())

# %% [markdown]
# #### #6 Plot the result of the prediction on a portion of the test set

# %%
def title(y_pred, y_test, target_names, i):
    pred_name = target_names[y_pred[i]].rsplit(' ', 1)[-1]
    true_name = target_names[y_test[i]].rsplit(' ', 1)[-1]
    return 'predicted: %s\ntrue:      %s' % (pred_name, true_name)

# %%
prediction_titles = [title(y_pred, y_test, target_names, i)
                         for i in range(y_pred.shape[0])]

# %%
plot_gallery(X_test, prediction_titles, h, w)

# %% [markdown]
# #### #7 Plot the gallery of the most significative eigenfaces

# %%
eigenface_titles = ["eigenface %d" % i for i in range(eigenfaces.shape[0])]
plot_gallery(eigenfaces, eigenface_titles, h, w)

pl.show()

# %% [markdown]
# #### #8 How much of the variance is explained by the first principal component? The second?

# %%
pca.explained_variance_
# Out:
# array([8.531037  , 5.744606  , 2.7505121 , 2.3070898 , 2.003097  ,
#        1.1217427 , 0.9793693 , 0.86547756, 0.77775264, 0.7380077 ,
#        0.6413938 , 0.6162426 , 0.48430014, 0.4216971 , 0.42063487,
#        0.38593626, 0.35333887, 0.33445448, 0.32759443, 0.29460114,
#        0.27528748, 0.2565085 , 0.25478217, 0.2229385 , 0.21121782,
#        0.20886104, 0.20319997, 0.19378997, 0.1770279 , 0.16994287,
#        0.15913722, 0.15782301, 0.14647849, 0.14153548, 0.1394015 ,
#        0.13448532, 0.12995122, 0.12351099, 0.11953753, 0.11736877,
#        0.11315668, 0.1098741 , 0.106809  , 0.10651324, 0.10054225,
#        0.09965494, 0.09850144, 0.09161472, 0.08924814, 0.08747175,
#        0.08730929, 0.08494797, 0.08448943, 0.0830222 , 0.08127677,
#        0.07724788, 0.07656709, 0.07582329, 0.07364877, 0.07290263,
#        0.06995089, 0.06793971, 0.0664286 , 0.06516826, 0.0641885 ,
#        0.06232862, 0.06079938, 0.0604543 , 0.05984409, 0.05930133,
#        0.05755125, 0.0569967 , 0.05617959, 0.05454267, 0.05365178,
#        0.05296093, 0.05182169, 0.05025234, 0.04967496, 0.04951374,
#        0.04883144, 0.04862593, 0.04744357, 0.04718456, 0.0465676 ,
#        0.04571894, 0.04444845, 0.04414587, 0.0431318 , 0.04219613,
#        0.04193376, 0.04056267, 0.03962405, 0.03898473, 0.03848575,
#        0.0382724 , 0.03733494, 0.03660761, 0.03644021, 0.03539276,
#        0.03508764, 0.03446923, 0.03432634, 0.03388743, 0.03365063,
#        0.03272381, 0.03219924, 0.03201241, 0.0313235 , 0.03120214,
#        0.02986079, 0.0294664 , 0.02921698, 0.0288379 , 0.02843657,
#        0.02817653, 0.02787278, 0.02741276, 0.02690429, 0.02635246,
#        0.02612071, 0.02591099, 0.02532406, 0.02489965, 0.02450672,
#        0.02444582, 0.02408955, 0.02387311, 0.02375575, 0.0234293 ,
#        0.02295911, 0.02244899, 0.02228241, 0.021714  , 0.02157321,
#        0.02133654, 0.02114113, 0.02095317, 0.02060884, 0.02033524,
#        0.01989588, 0.0195343 , 0.01926392, 0.01920458, 0.01867483,
#        0.01864738, 0.01836688, 0.01816406, 0.01784389, 0.01747745],
#       dtype=float32)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.2086042 , 0.14046931, 0.06725658, 0.05641384, 0.0489805 ,
#        0.02742928, 0.02394791, 0.02116299, 0.0190179 , 0.01804605,
#        0.01568361, 0.0150686 , 0.01184229, 0.0103115 , 0.01028552,
#        0.00943706, 0.00863998, 0.00817821, 0.00801046, 0.0072037 ,
#        0.00673143, 0.00627224, 0.00623003, 0.00545138, 0.00516478,
#        0.00510715, 0.00496872, 0.00473863, 0.00432875, 0.00415551,
#        0.00389128, 0.00385915, 0.00358175, 0.00346088, 0.0034087 ,
#        0.00328849, 0.00317762, 0.00302014, 0.00292298, 0.00286995,
#        0.00276695, 0.00268668, 0.00261173, 0.0026045 , 0.0024585 ,
#        0.0024368 , 0.00240859, 0.0022402 , 0.00218233, 0.00213889,
#        0.00213492, 0.00207718, 0.00206597, 0.00203009, 0.00198741,
#        0.00188889, 0.00187225, 0.00185406, 0.00180089, 0.00178264,
#        0.00171047, 0.00166129, 0.00162434, 0.00159352, 0.00156956,
#        0.00152408, 0.00148669, 0.00147825, 0.00146333, 0.00145006,
#        0.00140727, 0.00139371, 0.00137373, 0.0013337 , 0.00131191,
#        0.00129502, 0.00126716, 0.00122879, 0.00121467, 0.00121073,
#        0.00119405, 0.00118902, 0.00116011, 0.00115378, 0.00113869,
#        0.00111794, 0.00108687, 0.00107947, 0.00105468, 0.0010318 ,
#        0.00102538, 0.00099185, 0.0009689 , 0.00095327, 0.00094107,
#        0.00093585, 0.00091293, 0.00089514, 0.00089105, 0.00086544,
#        0.00085798, 0.00084285, 0.00083936, 0.00082863, 0.00082284,
#        0.00080018, 0.00078735, 0.00078278, 0.00076593, 0.00076297,
#        0.00073017, 0.00072052, 0.00071442, 0.00070516, 0.00069534,
#        0.00068898, 0.00068156, 0.00067031, 0.00065787, 0.00064438,
#        0.00063871, 0.00063359, 0.00061923, 0.00060886, 0.00059925,
#        0.00059776, 0.00058905, 0.00058375, 0.00058088, 0.0005729 ,
#        0.0005614 , 0.00054893, 0.00054486, 0.00053096, 0.00052752,
#        0.00052173, 0.00051695, 0.00051235, 0.00050394, 0.00049725,
#        0.0004865 , 0.00047766, 0.00047105, 0.0004696 , 0.00045664,
#        0.00045597, 0.00044911, 0.00044415, 0.00043633, 0.00042737],
#       dtype=float32)

# %%
print (pca.explained_variance_ratio_.cumsum())
# Out:
# [0.2086042  0.34907353 0.4163301  0.47274393 0.5217244  0.5491537
#  0.5731016  0.59426457 0.61328244 0.63132846 0.64701205 0.66208065
#  0.67392296 0.68423444 0.69451994 0.703957   0.712597   0.72077525
#  0.7287857  0.7359894  0.74272084 0.7489931  0.75522316 0.76067454
#  0.76583934 0.7709465  0.7759152  0.78065383 0.78498256 0.7891381
#  0.79302937 0.79688853 0.8004703  0.8039312  0.80733985 0.81062835
#  0.813806   0.81682616 0.8197491  0.8226191  0.82538605 0.8280727
#  0.8306845  0.83328897 0.8357475  0.8381843  0.8405929  0.8428331
#  0.8450154  0.8471543  0.84928924 0.8513664  0.85343236 0.85546243
#  0.8574498  0.8593387  0.86121094 0.863065   0.8648659  0.86664855
#  0.868359   0.87002033 0.8716447  0.8732382  0.8748078  0.87633187
#  0.8778186  0.87929684 0.8807602  0.88221025 0.8836175  0.8850112
#  0.8863849  0.8877186  0.8890305  0.89032555 0.8915927  0.8928215
#  0.8940362  0.8952469  0.896441   0.89763    0.89879006 0.8999438
#  0.9010825  0.90220046 0.90328735 0.90436685 0.90542156 0.9064534
#  0.90747875 0.90847063 0.9094395  0.91039276 0.91133386 0.9122697
#  0.9131826  0.91407776 0.9149688  0.91583425 0.9166922  0.91753507
#  0.9183744  0.91920304 0.9200259  0.9208261  0.92161345 0.92239624
#  0.92316216 0.9239251  0.92465526 0.92537576 0.9260902  0.92679536
#  0.9274907  0.9281797  0.92886126 0.9295316  0.93018943 0.9308338
#  0.93147254 0.93210614 0.93272537 0.93333423 0.9339335  0.9345313
#  0.93512034 0.9357041  0.936285   0.93685794 0.93741935 0.9379683
#  0.93851316 0.9390441  0.9395716  0.94009334 0.9406103  0.94112265
#  0.9416266  0.94212383 0.9426103  0.943088   0.94355905 0.9440287
#  0.9444853  0.9449413  0.9453904  0.9458346  0.9462709  0.94669825]

# %%
#sum up lambda's
accum = pca.explained_variance_ratio_
sum = 0.0
for i in range(pca.explained_variance_ratio_.shape[0]):
  accum[i] = sum + pca.explained_variance_ratio_[i]
  sum = accum[i]
print(accum)
# Out:
# [0.2086042  0.34907353 0.4163301  0.47274393 0.5217244  0.5491537
#  0.5731016  0.59426457 0.61328244 0.63132846 0.64701205 0.66208065
#  0.67392296 0.68423444 0.69451994 0.703957   0.712597   0.72077525
#  0.7287857  0.7359894  0.74272084 0.7489931  0.75522316 0.76067454
#  0.76583934 0.7709465  0.7759152  0.78065383 0.78498256 0.7891381
#  0.79302937 0.79688853 0.8004703  0.8039312  0.80733985 0.81062835
#  0.813806   0.81682616 0.8197491  0.8226191  0.82538605 0.8280727
#  0.8306845  0.83328897 0.8357475  0.8381843  0.8405929  0.8428331
#  0.8450154  0.8471543  0.84928924 0.8513664  0.85343236 0.85546243
#  0.8574498  0.8593387  0.86121094 0.863065   0.8648659  0.86664855
#  0.868359   0.87002033 0.8716447  0.8732382  0.8748078  0.87633187
#  0.8778186  0.87929684 0.8807602  0.88221025 0.8836175  0.8850112
#  0.8863849  0.8877186  0.8890305  0.89032555 0.8915927  0.8928215
#  0.8940362  0.8952469  0.896441   0.89763    0.89879006 0.8999438
#  0.9010825  0.90220046 0.90328735 0.90436685 0.90542156 0.9064534
#  0.90747875 0.90847063 0.9094395  0.91039276 0.91133386 0.9122697
#  0.9131826  0.91407776 0.9149688  0.91583425 0.9166922  0.91753507
#  0.9183744  0.91920304 0.9200259  0.9208261  0.92161345 0.92239624
#  0.92316216 0.9239251  0.92465526 0.92537576 0.9260902  0.92679536
#  0.9274907  0.9281797  0.92886126 0.9295316  0.93018943 0.9308338
#  0.93147254 0.93210614 0.93272537 0.93333423 0.9339335  0.9345313
#  0.93512034 0.9357041  0.936285   0.93685794 0.93741935 0.9379683
#  0.93851316 0.9390441  0.9395716  0.94009334 0.9406103  0.94112265
#  0.9416266  0.94212383 0.9426103  0.943088   0.94355905 0.9440287
#  0.9444853  0.9449413  0.9453904  0.9458346  0.9462709  0.94669825]

# %% [markdown]
# #### #9 How many PCs to use? As you add more principal components as features for training your classifier, do you expect it to get better or worse performance?
#
# Now you'll experiment with keeping different numbers of principal components. In a multiclass classification problem like this one (more than 2 labels to apply), accuracy is a less-intuitive metric than in the 2-class case. Instead, a popular metric is the F1 score.
#
# While ideally, adding components should provide us additional signal to improve our performance, it is possible that we end up at a complexity where we overfit.

# %%
scores = []
scores.append(10)

# %%
# the original dimensionality is over 1800
#n_components = 150

#change to n_components for 50%, 60%, 70%, 80%, 90%, 95%
scores = []
for n_components in [10, 15, 25, 50, 70, 80, 100, 110, 120, 130, 140, 160, 180, 200, 250]:
    print("Extracting the top %d eigenfaces from %d faces" % (n_components, X_train.shape[0]))
    t0 = time()
    # create the PCA
    pca = RandomizedPCA(n_components=n_components, whiten=True).fit(X_train)
    print("done in %0.3fs" % (time() - t0))

    # principle components of the face data
    # reshape the data so they can look like pictures
    eigenfaces = pca.components_.reshape((n_components, h, w))

    print("Projecting the input data on the eigenfaces orthonormal basis")
    t0 = time()
    # transform the data into the principle component representation
    X_train_pca = pca.transform(X_train)
    X_test_pca = pca.transform(X_test)
    print("done in %0.3fs" % (time() - t0))

    print("Fitting the classifier to the training set")
    t0 = time()
    #use the hyperparameters found earlier here
    clf = SVC(C=1000.0, class_weight='balanced', gamma=0.005)
    '''
    param_grids = {
        'C': [1e3, 5e3, 1e4, 5e4, 1e5],
        'gamma':  [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.1]
    }
    # create the classifier with all pairings of "C", and "Gamma" hyperparameters
    clf = GridSearchCV(SVC(kernel='rbf', class_weight='balanced'), param_grids)
    '''
    # fit the data
    clf = clf.fit(X_train_pca, y_train)
    print('done in %0.3fs' % (time() - t0))

    # print('Best estimator fount in grid search:')
    # print(clf.best_estimator_)

    print("Predicting the people names on the testing set")
    t0 = time()
    y_pred = clf.predict(X_test_pca)
    print('done in %0.3fs' % (time() - t0))

    print(classification_report(y_test, y_pred, target_names=target_names))
    print(confusion_matrix(y_test, y_pred, labels=range(n_classes)))
    scores.append((n_components, clf.score(X_test_pca, y_test)))
# Out:
# Extracting the top 10 eigenfaces from 966 faces
# done in 0.158s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.027s
# Fitting the classifier to the training set
# done in 0.701s
# Predicting the people names on the testing set
# done in 0.039s
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.12      0.38      0.19        13
#      Colin Powell       0.47      0.43      0.45        60
#   Donald Rumsfeld       0.32      0.48      0.38        27
#     George W Bush       0.74      0.40      0.52       146
# Gerhard Schroeder       0.23      0.32      0.27        25
#       Hugo Chavez       0.17      0.40      0.24        15
#        Tony Blair       0.40      0.39      0.39        36
#
#          accuracy                           0.41       322
#         macro avg       0.35      0.40      0.35       322
#      weighted avg       0.52      0.41      0.44       322
#
# [[ 5  2  3  1  1  1  0]
#  [16 26  4  3  7  3  1]
#  [ 3  5 13  3  1  1  1]
#  [14 16  9 59 16 18 14]
#  [ 0  1  3  5  8  4  4]
#  [ 1  2  0  4  1  6  1]
#  [ 1  3  9  5  1  3 14]]
# Extracting the top 15 eigenfaces from 966 faces
# done in 0.290s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.025s
# Fitting the classifier to the training set
# done in 0.356s
# Predicting the people names on the testing set
# done in 0.018s
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.25      0.38      0.30        13
#      Colin Powell       0.60      0.73      0.66        60
#   Donald Rumsfeld       0.38      0.52      0.44        27
#     George W Bush       0.79      0.65      0.71       146
# Gerhard Schroeder       0.42      0.52      0.46        25
#       Hugo Chavez       0.55      0.40      0.46        15
#        Tony Blair       0.53      0.44      0.48        36
#
#          accuracy                           0.60       322
#         macro avg       0.50      0.52      0.50       322
#      weighted avg       0.63      0.60      0.61       322
#
# [[ 5  4  3  1  0  0  0]
#  [ 7 44  2  5  1  0  1]
#  [ 4  2 14  7  0  0  0]
#  [ 3 17 14 95  6  4  7]
#  [ 0  0  1  6 13  0  5]
#  [ 0  3  0  2  3  6  1]
#  [ 1  3  3  4  8  1 16]]
# Extracting the top 25 eigenfaces from 966 faces
# done in 0.143s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.013s
# Fitting the classifier to the training set
# done in 0.168s
# Predicting the people names on the testing set
# done in 0.017s
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.44      0.54      0.48        13
#      Colin Powell       0.68      0.82      0.74        60
#   Donald Rumsfeld       0.42      0.52      0.47        27
#     George W Bush       0.85      0.80      0.82       146
# Gerhard Schroeder       0.56      0.56      0.56        25
#       Hugo Chavez       0.88      0.47      0.61        15
#        Tony Blair       0.67      0.56      0.61        36
#
#          accuracy                           0.71       322
#         macro avg       0.64      0.61      0.61       322
#      weighted avg       0.72      0.71      0.71       322
#
# [[  7   4   2   0   0   0   0]
#  [  2  49   5   4   0   0   0]
#  [  3   1  14   7   1   0   1]
#  [  3  11   9 117   3   0   3]
#  [  0   0   2   5  14   0   4]
#  [  0   3   0   1   2   7   2]
#  [  1   4   1   4   5   1  20]]
# Extracting the top 50 eigenfaces from 966 faces
# done in 0.213s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.014s
# Fitting the classifier to the training set
# done in 0.130s
# Predicting the people names on the testing set
# done in 0.019s
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.60      0.69      0.64        13
#      Colin Powell       0.80      0.88      0.84        60
#   Donald Rumsfeld       0.67      0.59      0.63        27
#     George W Bush       0.87      0.88      0.87       146
# Gerhard Schroeder       0.63      0.68      0.65        25
#       Hugo Chavez       0.80      0.53      0.64        15
#        Tony Blair       0.73      0.67      0.70        36
#
#          accuracy                           0.79       322
#         macro avg       0.73      0.70      0.71       322
#      weighted avg       0.79      0.79      0.79       322
#
# [[  9   1   3   0   0   0   0]
#  [  0  53   0   5   0   0   2]
#  [  2   2  16   6   1   0   0]
#  [  2   7   4 128   1   1   3]
#  [  0   0   1   3  17   1   3]
#  [  0   2   0   0   4   8   1]
#  [  2   1   0   5   4   0  24]]
# Extracting the top 70 eigenfaces from 966 faces
# done in 0.297s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.014s
# Fitting the classifier to the training set
# done in 0.113s
# Predicting the people names on the testing set
# done in 0.029s
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.64      0.69      0.67        13
#      Colin Powell       0.78      0.87      0.82        60
#   Donald Rumsfeld       0.69      0.67      0.68        27
#     George W Bush       0.91      0.89      0.90       146
# Gerhard Schroeder       0.73      0.76      0.75        25
#       Hugo Chavez       0.91      0.67      0.77        15
#        Tony Blair       0.71      0.69      0.70        36
#
#          accuracy                           0.82       322
#         macro avg       0.77      0.75      0.75       322
#      weighted avg       0.82      0.82      0.82       322
#
# [[  9   0   3   1   0   0   0]
#  [  0  52   1   4   1   0   2]
#  [  3   2  18   3   0   1   0]
#  [  1   9   2 130   1   0   3]
#  [  0   0   1   1  19   0   4]
#  [  0   2   0   1   1  10   1]
#  [  1   2   1   3   4   0  25]]
# Extracting the top 80 eigenfaces from 966 faces
# done in 0.355s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.024s
# Fitting the classifier to the training set
# done in 0.147s
# Predicting the people names on the testing set
# done in 0.025s
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.69      0.69      0.69        13
#      Colin Powell       0.81      0.90      0.85        60
#   Donald Rumsfeld       0.63      0.63      0.63        27
#     George W Bush       0.90      0.91      0.91       146
# Gerhard Schroeder       0.77      0.68      0.72        25
#       Hugo Chavez       0.92      0.73      0.81        15
#        Tony Blair       0.76      0.72      0.74        36
#
#          accuracy                           0.83       322
#         macro avg       0.78      0.75      0.77       322
#      weighted avg       0.83      0.83      0.83       322
#
# [[  9   0   3   1   0   0   0]
#  [  0  54   2   3   1   0   0]
#  [  3   2  17   5   0   0   0]
#  [  0   7   3 133   0   1   2]
#  [  0   1   1   2  17   0   4]
#  [  0   2   0   0   0  11   2]
#  [  1   1   1   3   4   0  26]]
# Extracting the top 100 eigenfaces from 966 faces
# done in 0.280s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.018s
# Fitting the classifier to the training set
# done in 0.157s
# Predicting the people names on the testing set
# done in 0.050s
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.69      0.69      0.69        13
#      Colin Powell       0.82      0.92      0.87        60
#   Donald Rumsfeld       0.81      0.63      0.71        27
#     George W Bush       0.87      0.95      0.91       146
# Gerhard Schroeder       0.95      0.76      0.84        25
#       Hugo Chavez       1.00      0.67      0.80        15
#        Tony Blair       0.87      0.75      0.81        36
#
#          accuracy                           0.86       322
#         macro avg       0.86      0.77      0.80       322
#      weighted avg       0.86      0.86      0.85       322
#
# [[  9   0   2   2   0   0   0]
#  [  0  55   0   5   0   0   0]
#  [  2   3  17   5   0   0   0]
#  [  1   4   1 139   0   0   1]
#  [  0   2   0   2  19   0   2]
#  [  0   3   0   1   0  10   1]
#  [  1   0   1   6   1   0  27]]
# Extracting the top 110 eigenfaces from 966 faces
# done in 0.273s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.033s
# Fitting the classifier to the training set
# done in 0.218s
# Predicting the people names on the testing set
# done in 0.046s
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.71      0.77      0.74        13
#      Colin Powell       0.83      0.88      0.85        60
#   Donald Rumsfeld       0.81      0.63      0.71        27
#     George W Bush       0.89      0.96      0.92       146
# Gerhard Schroeder       0.95      0.80      0.87        25
#       Hugo Chavez       0.91      0.67      0.77        15
#        Tony Blair       0.88      0.81      0.84        36
#
#          accuracy                           0.87       322
#         macro avg       0.85      0.79      0.81       322
#      weighted avg       0.87      0.87      0.86       322
#
# [[ 10   0   2   1   0   0   0]
#  [  0  53   0   5   0   1   1]
#  [  3   2  17   5   0   0   0]
#  [  1   4   1 140   0   0   0]
#  [  0   1   0   2  20   0   2]
#  [  0   3   0   1   0  10   1]
#  [  0   1   1   4   1   0  29]]
# Extracting the top 120 eigenfaces from 966 faces
# done in 0.243s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.028s
# Fitting the classifier to the training set
# done in 0.224s
# Predicting the people names on the testing set
# done in 0.041s
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.69      0.69      0.69        13
#      Colin Powell       0.81      0.90      0.85        60
#   Donald Rumsfeld       0.86      0.67      0.75        27
#     George W Bush       0.88      0.96      0.92       146
# Gerhard Schroeder       0.91      0.80      0.85        25
#       Hugo Chavez       1.00      0.60      0.75        15
#        Tony Blair       0.94      0.81      0.87        36
#
#          accuracy                           0.87       322
#         macro avg       0.87      0.77      0.81       322
#      weighted avg       0.87      0.87      0.86       322
#
# [[  9   1   1   2   0   0   0]
#  [  2  54   0   4   0   0   0]
#  [  2   2  18   5   0   0   0]
#  [  0   5   1 140   0   0   0]
#  [  0   1   0   3  20   0   1]
#  [  0   3   0   1   1   9   1]
#  [  0   1   1   4   1   0  29]]
# Extracting the top 130 eigenfaces from 966 faces
# done in 0.334s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.024s
# Fitting the classifier to the training set
# done in 0.188s
# Predicting the people names on the testing set
# done in 0.057s
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.73      0.62      0.67        13
#      Colin Powell       0.81      0.90      0.85        60
#   Donald Rumsfeld       0.76      0.59      0.67        27
#     George W Bush       0.88      0.97      0.92       146
# Gerhard Schroeder       0.87      0.80      0.83        25
#       Hugo Chavez       1.00      0.60      0.75        15
#        Tony Blair       0.93      0.75      0.83        36
#
#          accuracy                           0.86       322
#         macro avg       0.85      0.75      0.79       322
#      weighted avg       0.86      0.86      0.85       322
#
# [[  8   1   2   2   0   0   0]
#  [  1  54   1   4   0   0   0]
#  [  2   2  16   7   0   0   0]
#  [  0   3   1 142   0   0   0]
#  [  0   2   0   2  20   0   1]
#  [  0   3   0   1   1   9   1]
#  [  0   2   1   4   2   0  27]]
# Extracting the top 140 eigenfaces from 966 faces
# done in 0.327s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.037s
# Fitting the classifier to the training set
# done in 0.245s
# Predicting the people names on the testing set
# done in 0.058s
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.80      0.62      0.70        13
#      Colin Powell       0.82      0.88      0.85        60
#   Donald Rumsfeld       0.81      0.63      0.71        27
#     George W Bush       0.85      0.97      0.91       146
# Gerhard Schroeder       0.95      0.80      0.87        25
#       Hugo Chavez       1.00      0.47      0.64        15
#        Tony Blair       0.97      0.83      0.90        36
#
#          accuracy                           0.86       322
#         macro avg       0.89      0.74      0.79       322
#      weighted avg       0.87      0.86      0.85       322
#
# [[  8   1   1   3   0   0   0]
#  [  2  53   1   4   0   0   0]
#  [  0   2  17   8   0   0   0]
#  [  0   4   0 142   0   0   0]
#  [  0   1   0   3  20   0   1]
#  [  0   3   0   4   1   7   0]
#  [  0   1   2   3   0   0  30]]
# Extracting the top 160 eigenfaces from 966 faces
# done in 0.496s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.035s
# Fitting the classifier to the training set
# done in 0.236s
# Predicting the people names on the testing set
# done in 0.067s
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.88      0.54      0.67        13
#      Colin Powell       0.82      0.88      0.85        60
#   Donald Rumsfeld       0.95      0.67      0.78        27
#     George W Bush       0.82      0.97      0.89       146
# Gerhard Schroeder       0.95      0.80      0.87        25
#       Hugo Chavez       1.00      0.53      0.70        15
#        Tony Blair       1.00      0.78      0.88        36
#
#          accuracy                           0.86       322
#         macro avg       0.92      0.74      0.80       322
#      weighted avg       0.87      0.86      0.85       322
#
# [[  7   1   0   5   0   0   0]
#  [  1  53   0   6   0   0   0]
#  [  0   1  18   8   0   0   0]
#  [  0   4   0 142   0   0   0]
#  [  0   1   0   4  20   0   0]
#  [  0   3   0   3   1   8   0]
#  [  0   2   1   5   0   0  28]]
# Extracting the top 180 eigenfaces from 966 faces
# done in 0.416s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.039s
# Fitting the classifier to the training set
# done in 0.263s
# Predicting the people names on the testing set
# done in 0.071s
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       1.00      0.54      0.70        13
#      Colin Powell       0.82      0.90      0.86        60
#   Donald Rumsfeld       0.93      0.52      0.67        27
#     George W Bush       0.79      0.98      0.88       146
# Gerhard Schroeder       1.00      0.76      0.86        25
#       Hugo Chavez       1.00      0.47      0.64        15
#        Tony Blair       1.00      0.78      0.88        36
#
#          accuracy                           0.84       322
#         macro avg       0.94      0.71      0.78       322
#      weighted avg       0.87      0.84      0.84       322
#
# [[  7   1   0   5   0   0   0]
#  [  0  54   0   6   0   0   0]
#  [  0   2  14  11   0   0   0]
#  [  0   3   0 143   0   0   0]
#  [  0   1   0   5  19   0   0]
#  [  0   3   0   5   0   7   0]
#  [  0   2   1   5   0   0  28]]
# Extracting the top 200 eigenfaces from 966 faces
# done in 0.424s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.043s
# Fitting the classifier to the training set
# done in 0.301s
# Predicting the people names on the testing set
# done in 0.076s
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       1.00      0.38      0.56        13
#      Colin Powell       0.82      0.88      0.85        60
#   Donald Rumsfeld       1.00      0.56      0.71        27
#     George W Bush       0.77      0.99      0.86       146
# Gerhard Schroeder       0.94      0.68      0.79        25
#       Hugo Chavez       1.00      0.47      0.64        15
#        Tony Blair       0.96      0.67      0.79        36
#
#          accuracy                           0.82       322
#         macro avg       0.93      0.66      0.74       322
#      weighted avg       0.85      0.82      0.81       322
#
# [[  5   2   0   6   0   0   0]
#  [  0  53   0   7   0   0   0]
#  [  0   1  15  11   0   0   0]
#  [  0   2   0 144   0   0   0]
#  [  0   1   0   6  17   0   1]
#  [  0   3   0   4   1   7   0]
#  [  0   3   0   9   0   0  24]]
# Extracting the top 250 eigenfaces from 966 faces
# done in 0.600s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.044s
# Fitting the classifier to the training set
# done in 0.316s
# Predicting the people names on the testing set
# done in 0.100s
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       1.00      0.31      0.47        13
#      Colin Powell       0.86      0.85      0.86        60
#   Donald Rumsfeld       1.00      0.44      0.62        27
#     George W Bush       0.69      0.99      0.82       146
# Gerhard Schroeder       1.00      0.40      0.57        25
#       Hugo Chavez       1.00      0.40      0.57        15
#        Tony Blair       0.91      0.56      0.69        36
#
#          accuracy                           0.77       322
#         macro avg       0.92      0.56      0.66       322
#      weighted avg       0.83      0.77      0.75       322
#
# [[  4   1   0   8   0   0   0]
#  [  0  51   0   9   0   0   0]
#  [  0   1  12  14   0   0   0]
#  [  0   1   0 145   0   0   0]
#  [  0   1   0  12  10   0   2]
#  [  0   2   0   7   0   6   0]
#  [  0   2   0  14   0   0  20]]

# %%
scores
# Out:
# [(10, 0.40683229813664595),
#  (15, 0.5993788819875776),
#  (25, 0.7080745341614907),
#  (50, 0.7919254658385093),
#  (70, 0.8167701863354038),
#  (80, 0.8291925465838509),
#  (100, 0.8571428571428571),
#  (110, 0.8664596273291926),
#  (120, 0.8664596273291926),
#  (130, 0.8571428571428571),
#  (140, 0.860248447204969),
#  (160, 0.8571428571428571),
#  (180, 0.84472049689441),
#  (200, 0.8229813664596274),
#  (250, 0.7701863354037267)]

# %% [markdown]
# #### #10 If you see a higher F1 score, does it mean the classifier is doing better, or worse?
#
# Yes, higher means better!

# %% [markdown]
# #### #11 Do you see any evidence of overfitting when using a large number of PCs? Does the dimensionality reduction of PCA seem to be helping your performance here?
#
# Yes, the F1 score starts to drop.
#
# #### #12 Selecting a Number of Principal Components
#
# * train on different number of PCs and see how accuracy responds - cut off when it comes apparent that adding more PCs doesn't buy you more discrimination.
#
# * this can be done also in feature selection as well. You don't want to do feature selection before going into PCA. PCA is going to combine information from potentially many different input features together
